# %%
# !pip install comet_ml --quiet

import comet_ml
comet_ml.login()

import numpy as np
import matplotlib.pyplot as plt
import cv2
from scipy import io
from tensorflow.keras.models import Sequential
from tensorflow.keras.constraints import MaxNorm
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import regularizers

def build_model_graph(experiment):
    model = Sequential()
    model.add(Dense(experiment.get_parameter("first_layer_units"),
                    input_shape=(400,),
                    activation='relu',
                    kernel_constraint=MaxNorm(3),
                    kernel_regularizer=experiment.get_parameter("k_r")))
    model.add(Dropout(0.2))
    model.add(Dense(200, activation='relu',
                    kernel_constraint=MaxNorm(3),
                    kernel_regularizer=experiment.get_parameter("k_r")))
    model.add(Dropout(0.2))
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

def train(experiment, model, X_tr, Y_tr):
    history = model.fit(X_tr, Y_tr,
                        batch_size=experiment.get_parameter("batch_size"),
                        epochs=experiment.get_parameter("epochs"),
                        validation_split=0.2)
    experiment.log_metric("loss", history.history['loss'][-1])
    experiment.log_metric("val_loss", history.history['val_loss'][-1])
    return history

def evaluate(experiment, model, X_te, Y_te):
    score = model.evaluate(X_te, Y_te, verbose=0)
    experiment.log_metric("test_loss", score[0])
    experiment.log_metric("test_accuracy", score[1])
    print("Test Loss:", score[0])
    print("Test Accuracy:", score[1])
    return score

def get_dataset():
    dataset = io.loadmat('/content/Data_hoda_full.mat')
    x_tr = np.squeeze(dataset['Data'][:10000])
    y_tr = np.squeeze(dataset['labels'][:10000])
    x_te = np.squeeze(dataset['Data'][10000:12000])
    y_te = np.squeeze(dataset['labels'][10000:12000])
    width, height = 20, 20
    X_tr = np.zeros((x_tr.shape[0], width*height))
    X_te = np.zeros((x_te.shape[0], width*height))
    for i, img in enumerate(x_tr):
        X_tr[i] = cv2.resize(img, (width, height), interpolation=cv2.INTER_NEAREST).ravel()/255
    for i, img in enumerate(x_te):
        X_te[i] = cv2.resize(img, (width, height), interpolation=cv2.INTER_NEAREST).ravel()/255
    Y_tr = to_categorical(y_tr, 10)
    Y_te = to_categorical(y_te, 10)
    return X_tr, Y_tr, X_te, Y_te, x_tr

X_tr, Y_tr, X_te, Y_te, raw_tr = get_dataset()

plt.figure(figsize=(3,3))
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.xticks([]); plt.yticks([]); plt.grid(False)
    plt.imshow(raw_tr[i], cmap='binary')
plt.show()

config = {
    "algorithm": "bayes",
    "name": "Optimize My Network",
    "spec": {"maxCombo": 5, "objective": "minimize", "metric": "loss"},
    "parameters": {
        "first_layer_units": {"type": "integer", "mu": 500, "sigma": 50, "scalingType": "normal"},
        "batch_size": {"type": "discrete", "values": [64, 128, 256]},
        "k_r": {"type": "categorical", "values": ["l1", "l2"]},
    },
    "trials": 2,
}

opt = comet_ml.Optimizer(config)

best_acc = 0
best_params = None

for experiment in opt.get_experiments():
    experiment.log_parameter("epochs", 50)
    model = build_model_graph(experiment)
    history = train(experiment, model, X_tr, Y_tr)
    score = evaluate(experiment, model, X_te, Y_te)
    trial_params = {
        "first_layer_units": experiment.get_parameter("first_layer_units"),
        "batch_size": experiment.get_parameter("batch_size"),
        "k_r": experiment.get_parameter("k_r"),
        "epochs": experiment.get_parameter("epochs")
    }
    if score[1] > best_acc:
        best_acc = score[1]
        best_params = trial_params
    plt.plot(history.history['loss'], label='Train Loss', color='red')
    plt.plot(history.history['val_loss'], label='Validation Loss', color='blue')
    plt.legend(); plt.show()
    plt.plot(history.history['accuracy'], label='Train Accuracy', color='red')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='blue')
    plt.legend(); plt.show()
    preds = model.predict(X_te[:5])
    for i in range(5):
        plt.imshow(X_te[i].reshape(20,20), cmap='binary')
        plt.title(f"True: {np.argmax(Y_te[i])}, Pred: {np.argmax(preds[i])}")
        plt.show()
    experiment.end()

print("Best Test Accuracy:", best_acc)
print("Best Parameters:", best_params)
# Out:
# COMET INFO: 2a5fe7b6095b40b0a3dc024e0e055ed1
# COMET INFO: Using optimizer config: {'algorithm': 'bayes', 'configSpaceSize': 'infinite', 'endTime': None, 'id': '2a5fe7b6095b40b0a3dc024e0e055ed1', 'lastUpdateTime': None, 'maxCombo': 5, 'name': 'Optimize My Network', 'parameters': {'batch_size': {'type': 'discrete', 'values': [64, 128, 256]}, 'first_layer_units': {'mu': 500, 'scalingType': 'normal', 'sigma': 50, 'type': 'integer'}, 'k_r': {'type': 'categorical', 'values': ['l1', 'l2']}}, 'predictor': None, 'spec': {'gridSize': 10, 'maxCombo': 5, 'metric': 'loss', 'minSampleSize': 100, 'objective': 'minimize', 'retryAssignLimit': 0, 'retryLimit': 1000}, 'startTime': 202068135, 'state': {'mode': None, 'seed': None, 'sequence': [], 'sequence_i': 0, 'sequence_pid': None, 'sequence_retry': 0, 'sequence_retry_count': 0}, 'status': 'running', 'suggestion_count': 0, 'trials': 2, 'version': '2.1.10'}
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/mehdi-moha/general/8b53af99105f4b82b3800370506d95a3
#
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Ignoring automatic log_parameter('verbose') because 'keras:verbose' is in COMET_LOGGING_PARAMETERS_IGNORE
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.3041 - loss: 106.8070 - val_accuracy: 0.7270 - val_loss: 53.8130
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6574 - loss: 41.5474 - val_accuracy: 0.7050 - val_loss: 13.2985
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5581 - loss: 9.1815 - val_accuracy: 0.6150 - val_loss: 3.2741
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5204 - loss: 2.9416 - val_accuracy: 0.7680 - val_loss: 2.1942
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6035 - loss: 2.2648 - val_accuracy: 0.8300 - val_loss: 1.9225
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6502 - loss: 2.0813 - val_accuracy: 0.8465 - val_loss: 1.7909
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6831 - loss: 1.9914 - val_accuracy: 0.8565 - val_loss: 1.7159
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6896 - loss: 1.9376 - val_accuracy: 0.8640 - val_loss: 1.6628
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7042 - loss: 1.8809 - val_accuracy: 0.8650 - val_loss: 1.6173
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7267 - loss: 1.8454 - val_accuracy: 0.8705 - val_loss: 1.5840
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7359 - loss: 1.7962 - val_accuracy: 0.8695 - val_loss: 1.5519
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7335 - loss: 1.8081 - val_accuracy: 0.8720 - val_loss: 1.5278
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7431 - loss: 1.7506 - val_accuracy: 0.8730 - val_loss: 1.5088
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7369 - loss: 1.7522 - val_accuracy: 0.8765 - val_loss: 1.4953
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.

# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# COMET WARNING: Couldn't retrieve and log Google Colab notebook content, reason: 'NoneType' object is not subscriptable
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : blushing_puma_8499
# COMET INFO:     url                   : https://www.comet.com/mehdi-moha/general/8b53af99105f4b82b3800370506d95a3
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [50]                : (0.4377500116825104, 0.809249997138977)
# COMET INFO:     batch_accuracy [200]         : (0.15234375, 0.828125)
# COMET INFO:     batch_loss [200]             : (1.3926057815551758, 127.45901489257812)
# COMET INFO:     epoch_duration [50]          : (0.6332384130000719, 3.335267120000026)
# COMET INFO:     loss [51]                    : (1.4424890279769897, 89.76720428466797)
# COMET INFO:     test_accuracy                : 0.9125000238418579
# COMET INFO:     test_loss                    : 1.2285534143447876
# COMET INFO:     val_accuracy [50]            : (0.6150000095367432, 0.9160000085830688)
# COMET INFO:     val_loss [51]                : (1.2116930484771729, 53.81303405761719)
# COMET INFO:     validate_batch_accuracy [50] : (0.609375, 0.93359375)
# COMET INFO:     validate_batch_loss [50]     : (1.2010281085968018, 53.811668395996094)
# COMET INFO:   Others:
# COMET INFO:     notebook_url           : https://colab.research.google.com/notebook#fileId=16rcyO1XAqsDI4NTJJPm63smWjtc_YnY3
# COMET INFO:     optimizer_count        : 1
# COMET INFO:     optimizer_id           : 2a5fe7b6095b40b0a3dc024e0e055ed1
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : 1.4424890279769897
# COMET INFO:     optimizer_name         : Optimize My Network
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"batch_size": 256, "first_layer_units": 483, "k_r": "l1"}
# COMET INFO:     optimizer_pid          : 72e21fc8c17388ea2b1d6182e566649305835a54
# COMET INFO:     optimizer_process      : 26263
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.1.10
# COMET INFO:     trainable_params       : 292493
# COMET INFO:   Parameters:
# COMET INFO:     Adam_amsgrad                     : False
# COMET INFO:     Adam_beta_1                      : 0.9
# COMET INFO:     Adam_beta_2                      : 0.999
# COMET INFO:     Adam_clipnorm                    : None
# COMET INFO:     Adam_clipvalue                   : None
# COMET INFO:     Adam_ema_momentum                : 0.99
# COMET INFO:     Adam_ema_overwrite_frequency     : None
# COMET INFO:     Adam_epsilon                     : 1e-07
# COMET INFO:     Adam_global_clipnorm             : None
# COMET INFO:     Adam_gradient_accumulation_steps : None
# COMET INFO:     Adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     Adam_loss_scale_factor           : None
# COMET INFO:     Adam_name                        : adam
# COMET INFO:     Adam_use_ema                     : False
# COMET INFO:     Adam_weight_decay                : None
# COMET INFO:     Optimizer                        : adam
# COMET INFO:     adam_amsgrad                     : False
# COMET INFO:     adam_beta_1                      : 0.9
# COMET INFO:     adam_beta_2                      : 0.999
# COMET INFO:     adam_clipnorm                    : None
# COMET INFO:     adam_clipvalue                   : None
# COMET INFO:     adam_ema_momentum                : 0.99
# COMET INFO:     adam_ema_overwrite_frequency     : None
# COMET INFO:     adam_epsilon                     : 1e-07
# COMET INFO:     adam_global_clipnorm             : None
# COMET INFO:     adam_gradient_accumulation_steps : None
# COMET INFO:     adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     adam_loss_scale_factor           : None
# COMET INFO:     adam_use_ema                     : False
# COMET INFO:     adam_weight_decay                : None
# COMET INFO:     batch_size                       : 256
# COMET INFO:     epochs                           : 50
# COMET INFO:     first_layer_units                : 483
# COMET INFO:     k_r                              : l1
# COMET INFO:     steps                            : 32
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7030 - loss: 1.6384 - val_accuracy: 0.8970 - val_loss: 1.3053
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7160 - loss: 1.5969 - val_accuracy: 0.9015 - val_loss: 1.2936
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7200 - loss: 1.5935 - val_accuracy: 0.8965 - val_loss: 1.2890
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7152 - loss: 1.6159 - val_accuracy: 0.8940 - val_loss: 1.2919
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7172 - loss: 1.6011 - val_accuracy: 0.8975 - val_loss: 1.2840
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7124 - loss: 1.5936 - val_accuracy: 0.9040 - val_loss: 1.2719
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7066 - loss: 1.6257 - val_accuracy: 0.8980 - val_loss: 1.2802
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7091 - loss: 1.6027 - val_accuracy: 0.9025 - val_loss: 1.2759
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7226 - loss: 1.5834 - val_accuracy: 0.8945 - val_loss: 1.2789
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7231 - loss: 1.5691 - val_accuracy: 0.9050 - val_loss: 1.2528
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7190 - loss: 1.5807 - val_accuracy: 0.9045 - val_loss: 1.2581
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.7178 - loss: 1.5671 - val_accuracy: 0.9010 - val_loss: 1.2563
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7222 - loss: 1.5666 - val_accuracy: 0.9055 - val_loss: 1.2394
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7176 - loss: 1.5763 - val_accuracy: 0.9085 - val_loss: 1.2433
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7254 - loss: 1.5696 - val_accuracy: 0.9075 - val_loss: 1.2461
# Test Loss: 1.2627589702606201
# Test Accuracy: 0.890500009059906
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# COMET WARNING: Couldn't retrieve and log Google Colab notebook content, reason: 'NoneType' object is not subscriptable
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : rapid_stalk_9949
# COMET INFO:     url                   : https://www.comet.com/mehdi-moha/general/57433512852b4e41a205050ddbe5724b
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [50]                : (0.4126250147819519, 0.7232499718666077)
# COMET INFO:     batch_accuracy [200]         : (0.12109375, 0.765625)
# COMET INFO:     batch_loss [200]             : (1.5001394748687744, 127.49404907226562)
# COMET INFO:     epoch_duration [50]          : (0.6861063360001936, 3.67345977199966)
# COMET INFO:     loss [51]                    : (1.5642856359481812, 89.6695556640625)
# COMET INFO:     test_accuracy                : 0.890500009059906
# COMET INFO:     test_loss                    : 1.2627589702606201
# COMET INFO:     val_accuracy [50]            : (0.5889999866485596, 0.9085000157356262)
# COMET INFO:     val_loss [51]                : (1.2394360303878784, 53.71477127075195)
# COMET INFO:     validate_batch_accuracy [50] : (0.609375, 0.90234375)
# COMET INFO:     validate_batch_loss [50]     : (1.2347629070281982, 53.714942932128906)
# COMET INFO:   Others:
# COMET INFO:     notebook_url           : https://colab.research.google.com/notebook#fileId=16rcyO1XAqsDI4NTJJPm63smWjtc_YnY3
# COMET INFO:     optimizer_count        : 2
# COMET INFO:     optimizer_id           : 2a5fe7b6095b40b0a3dc024e0e055ed1
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : 1.5642856359481812
# COMET INFO:     optimizer_name         : Optimize My Network
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"batch_size": 256, "first_layer_units": 483, "k_r": "l1"}
# COMET INFO:     optimizer_pid          : 72e21fc8c17388ea2b1d6182e566649305835a54
# COMET INFO:     optimizer_process      : 26263
# COMET INFO:     optimizer_trial        : 2
# COMET INFO:     optimizer_version      : 2.1.10
# COMET INFO:     trainable_params       : 292493
# COMET INFO:   Parameters:
# COMET INFO:     Adam_amsgrad                     : False
# COMET INFO:     Adam_beta_1                      : 0.9
# COMET INFO:     Adam_beta_2                      : 0.999
# COMET INFO:     Adam_clipnorm                    : None
# COMET INFO:     Adam_clipvalue                   : None
# COMET INFO:     Adam_ema_momentum                : 0.99
# COMET INFO:     Adam_ema_overwrite_frequency     : None
# COMET INFO:     Adam_epsilon                     : 1e-07
# COMET INFO:     Adam_global_clipnorm             : None
# COMET INFO:     Adam_gradient_accumulation_steps : None
# COMET INFO:     Adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     Adam_loss_scale_factor           : None
# COMET INFO:     Adam_name                        : adam
# COMET INFO:     Adam_use_ema                     : False
# COMET INFO:     Adam_weight_decay                : None
# COMET INFO:     Optimizer                        : adam
# COMET INFO:     adam_amsgrad                     : False
# COMET INFO:     adam_beta_1                      : 0.9
# COMET INFO:     adam_beta_2                      : 0.999
# COMET INFO:     adam_clipnorm                    : None
# COMET INFO:     adam_clipvalue                   : None
# COMET INFO:     adam_ema_momentum                : 0.99
# COMET INFO:     adam_ema_overwrite_frequency     : None
# COMET INFO:     adam_epsilon                     : 1e-07
# COMET INFO:     adam_global_clipnorm             : None
# COMET INFO:     adam_gradient_accumulation_steps : None
# COMET INFO:     adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     adam_loss_scale_factor           : None
# COMET INFO:     adam_use_ema                     : False
# COMET INFO:     adam_weight_decay                : None
# COMET INFO:     batch_size                       : 256
# COMET INFO:     epochs                           : 50
# COMET INFO:     first_layer_units                : 483
# COMET INFO:     k_r                              : l1
# COMET INFO:     steps                            : 32
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/mehdi-moha/general/45a965fca4014baea6169440c1fc2fa5
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.4585 - loss: 68.7988 - val_accuracy: 0.5015 - val_loss: 2.5694
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4042 - loss: 2.4235 - val_accuracy: 0.6660 - val_loss: 2.0064
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5363 - loss: 2.1274 - val_accuracy: 0.7205 - val_loss: 1.8046
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5617 - loss: 2.0379 - val_accuracy: 0.8110 - val_loss: 1.6614
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6201 - loss: 1.9518 - val_accuracy: 0.8480 - val_loss: 1.5802
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6556 - loss: 1.8786 - val_accuracy: 0.8655 - val_loss: 1.4993
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6618 - loss: 1.8547 - val_accuracy: 0.8675 - val_loss: 1.4712
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.6943 - loss: 1.7709 - val_accuracy: 0.8785 - val_loss: 1.4393
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6951 - loss: 1.7465 - val_accuracy: 0.8815 - val_loss: 1.4001
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6881 - loss: 1.7273 - val_accuracy: 0.8790 - val_loss: 1.3746
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7015 - loss: 1.6809 - val_accuracy: 0.8890 - val_loss: 1.3443
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6935 - loss: 1.7063 - val_accuracy: 0.8865 - val_loss: 1.3358
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7052 - loss: 1.6692 - val_accuracy: 0.8940 - val_loss: 1.3085
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7009 - loss: 1.6574 - val_accuracy: 0.8950 - val_loss: 1.2861
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7215 - loss: 1.6251 - val_accuracy: 0.8870 - val_loss: 1.3159
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7135 - loss: 1.6467 - val_accuracy: 0.8885 - val_loss: 1.2934
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7144 - loss: 1.6327 - val_accuracy: 0.8955 - val_loss: 1.2664
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [50]                 : (0.44999998807907104, 0.7426249980926514)
# COMET INFO:     batch_accuracy [650]          : (0.171875, 0.828125)
# COMET INFO:     batch_loss [650]              : (1.2842609882354736, 127.95723724365234)
# COMET INFO:     epoch_duration [50]           : (1.5000991910001176, 3.9137368709998555)
# COMET INFO:     loss [51]                     : (1.4720290899276733, 34.33852767944336)
# COMET INFO:     test_accuracy                 : 0.8960000276565552
# COMET INFO:     test_loss                     : 1.1701066493988037
# COMET INFO:     val_accuracy [50]             : (0.5015000104904175, 0.9089999794960022)
# COMET INFO:     val_loss [51]                 : (1.1293511390686035, 2.5693633556365967)
# COMET INFO:     validate_batch_accuracy [200] : (0.5, 0.921875)
# COMET INFO:     validate_batch_loss [200]     : (1.1081390380859375, 2.584778070449829)
# COMET INFO:   Others:
# COMET INFO:     notebook_url           : https://colab.research.google.com/notebook#fileId=16rcyO1XAqsDI4NTJJPm63smWjtc_YnY3
# COMET INFO:     optimizer_count        : 3
# COMET INFO:     optimizer_id           : 2a5fe7b6095b40b0a3dc024e0e055ed1
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : 1.4720290899276733
# COMET INFO:     optimizer_name         : Optimize My Network
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"batch_size": 64, "first_layer_units": 487, "k_r": "l1"}
# COMET INFO:     optimizer_pid          : 3230bda39b9d4bc43394caeb151dd94be6ba1738
# COMET INFO:     optimizer_process      : 26263
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.1.10
# COMET INFO:     trainable_params       : 294897
# COMET INFO:   Parameters:
# COMET INFO:     Adam_amsgrad                     : False
# COMET INFO:     Adam_beta_1                      : 0.9
# COMET INFO:     Adam_beta_2                      : 0.999
# COMET INFO:     Adam_clipnorm                    : None
# COMET INFO:     Adam_clipvalue                   : None
# COMET INFO:     Adam_ema_momentum                : 0.99
# COMET INFO:     Adam_ema_overwrite_frequency     : None
# COMET INFO:     Adam_epsilon                     : 1e-07
# COMET INFO:     Adam_global_clipnorm             : None
# COMET INFO:     Adam_gradient_accumulation_steps : None
# COMET INFO:     Adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     Adam_loss_scale_factor           : None
# COMET INFO:     Adam_name                        : adam
# COMET INFO:     Adam_use_ema                     : False
# COMET INFO:     Adam_weight_decay                : None
# COMET INFO:     Optimizer                        : adam
# COMET INFO:     adam_amsgrad                     : False
# COMET INFO:     adam_beta_1                      : 0.9
# COMET INFO:     adam_beta_2                      : 0.999
# COMET INFO:     adam_clipnorm                    : None
# COMET INFO:     adam_clipvalue                   : None
# COMET INFO:     adam_ema_momentum                : 0.99
# COMET INFO:     adam_ema_overwrite_frequency     : None
# COMET INFO:     adam_epsilon                     : 1e-07
# COMET INFO:     adam_global_clipnorm             : None
# COMET INFO:     adam_gradient_accumulation_steps : None
# COMET INFO:     adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     adam_loss_scale_factor           : None
# COMET INFO:     adam_use_ema                     : False
# COMET INFO:     adam_weight_decay                : None
# COMET INFO:     batch_size                       : 64
# COMET INFO:     epochs                           : 50
# COMET INFO:     first_layer_units                : 487
# COMET INFO:     k_r                              : l1
# COMET INFO:     steps                            : 125
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/mehdi-moha/general/1cb23878f1a54539a46e763fa801edb7
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0
# Epoch 38/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.7663 - loss: 1.4469 - val_accuracy: 0.9285 - val_loss: 1.1646
# Epoch 39/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7668 - loss: 1.4324 - val_accuracy: 0.9300 - val_loss: 1.1505
# Epoch 40/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7662 - loss: 1.4261 - val_accuracy: 0.9325 - val_loss: 1.1110
# Epoch 41/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7709 - loss: 1.4345 - val_accuracy: 0.9195 - val_loss: 1.1400
# Epoch 42/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7678 - loss: 1.4464 - val_accuracy: 0.9265 - val_loss: 1.1312
# Epoch 43/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7682 - loss: 1.4479 - val_accuracy: 0.9305 - val_loss: 1.1239
# Epoch 44/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7710 - loss: 1.4309 - val_accuracy: 0.9270 - val_loss: 1.1473
# Epoch 45/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7642 - loss: 1.4268 - val_accuracy: 0.9350 - val_loss: 1.1087
# Epoch 46/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7701 - loss: 1.4348 - val_accuracy: 0.9335 - val_loss: 1.1023
# Epoch 47/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7738 - loss: 1.4068 - val_accuracy: 0.9265 - val_loss: 1.1282
# Epoch 48/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7820 - loss: 1.4006 - val_accuracy: 0.9315 - val_loss: 1.1183
# Epoch 49/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7624 - loss: 1.4400 - val_accuracy: 0.9310 - val_loss: 1.1049
# Epoch 50/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7630 - loss: 1.4281 - val_accuracy: 0.9255 - val_loss: 1.1229
# Test Loss: 1.1388428211212158
# Test Accuracy: 0.9240000247955322
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# COMET WARNING: Couldn't retrieve and log Google Colab notebook content, reason: 'NoneType' object is not subscriptable
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : semantic_pavilion_5574
# COMET INFO:     url                   : https://www.comet.com/mehdi-moha/general/1cb23878f1a54539a46e763fa801edb7
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [50]                 : (0.5011249780654907, 0.7760000228881836)
# COMET INFO:     batch_accuracy [650]          : (0.03125, 0.84375)
# COMET INFO:     batch_loss [650]              : (1.2637330293655396, 127.75357055664062)
# COMET INFO:     epoch_duration [50]           : (1.5509365590000925, 4.149237219000042)
# COMET INFO:     loss [51]                     : (1.407975196838379, 34.11353302001953)
# COMET INFO:     test_accuracy                 : 0.9240000247955322
# COMET INFO:     test_loss                     : 1.1388428211212158
# COMET INFO:     val_accuracy [50]             : (0.6010000109672546, 0.9350000023841858)
# COMET INFO:     val_loss [51]                 : (1.1023305654525757, 2.5613396167755127)
# COMET INFO:     validate_batch_accuracy [200] : (0.515625, 0.9517045617103577)
# COMET INFO:     validate_batch_loss [200]     : (1.0847560167312622, 2.5867555141448975)
# COMET INFO:   Others:
# COMET INFO:     notebook_url           : https://colab.research.google.com/notebook#fileId=16rcyO1XAqsDI4NTJJPm63smWjtc_YnY3
# COMET INFO:     optimizer_count        : 4
# COMET INFO:     optimizer_id           : 2a5fe7b6095b40b0a3dc024e0e055ed1
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : 1.407975196838379
# COMET INFO:     optimizer_name         : Optimize My Network
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"batch_size": 64, "first_layer_units": 487, "k_r": "l1"}
# COMET INFO:     optimizer_pid          : 3230bda39b9d4bc43394caeb151dd94be6ba1738
# COMET INFO:     optimizer_process      : 26263
# COMET INFO:     optimizer_trial        : 2
# COMET INFO:     optimizer_version      : 2.1.10
# COMET INFO:     trainable_params       : 294897
# COMET INFO:   Parameters:
# COMET INFO:     Adam_amsgrad                     : False
# COMET INFO:     Adam_beta_1                      : 0.9
# COMET INFO:     Adam_beta_2                      : 0.999
# COMET INFO:     Adam_clipnorm                    : None
# COMET INFO:     Adam_clipvalue                   : None
# COMET INFO:     Adam_ema_momentum                : 0.99
# COMET INFO:     Adam_ema_overwrite_frequency     : None
# COMET INFO:     Adam_epsilon                     : 1e-07
# COMET INFO:     Adam_global_clipnorm             : None
# COMET INFO:     Adam_gradient_accumulation_steps : None
# COMET INFO:     Adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     Adam_loss_scale_factor           : None
# COMET INFO:     Adam_name                        : adam
# COMET INFO:     Adam_use_ema                     : False
# COMET INFO:     Adam_weight_decay                : None
# COMET INFO:     Optimizer                        : adam
# COMET INFO:     adam_amsgrad                     : False
# COMET INFO:     adam_beta_1                      : 0.9
# COMET INFO:     adam_beta_2                      : 0.999
# COMET INFO:     adam_clipnorm                    : None
# COMET INFO:     adam_clipvalue                   : None
# COMET INFO:     adam_ema_momentum                : 0.99
# COMET INFO:     adam_ema_overwrite_frequency     : None
# COMET INFO:     adam_epsilon                     : 1e-07
# COMET INFO:     adam_global_clipnorm             : None
# COMET INFO:     adam_gradient_accumulation_steps : None
# COMET INFO:     adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     adam_loss_scale_factor           : None
# COMET INFO:     adam_use_ema                     : False
# COMET INFO:     adam_weight_decay                : None
# COMET INFO:     batch_size                       : 64
# COMET INFO:     epochs                           : 50
# COMET INFO:     first_layer_units                : 487
# COMET INFO:     k_r                              : l1
# COMET INFO:     steps                            : 125
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# ...
# COMET INFO:     batch_accuracy [650]          : (0.140625, 1.0)
# COMET INFO:     batch_loss [650]              : (0.1767234206199646, 9.322444915771484)
# COMET INFO:     epoch_duration [50]           : (1.6169551160000992, 3.971840320999945)
# COMET INFO:     loss [51]                     : (0.23870155215263367, 3.7797775268554688)
# COMET INFO:     test_accuracy                 : 0.968999981880188
# COMET INFO:     test_loss                     : 0.2550491690635681
# COMET INFO:     val_accuracy [50]             : (0.9484999775886536, 0.9800000190734863)
# COMET INFO:     val_loss [51]                 : (0.21637381613254547, 1.498779535293579)
# COMET INFO:     validate_batch_accuracy [200] : (0.921875, 0.984375)
# COMET INFO:     validate_batch_loss [200]     : (0.20587123930454254, 1.5014915466308594)
# COMET INFO:   Others:
# COMET INFO:     notebook_url           : https://colab.research.google.com/notebook#fileId=16rcyO1XAqsDI4NTJJPm63smWjtc_YnY3
# COMET INFO:     optimizer_count        : 9
# COMET INFO:     optimizer_id           : 2a5fe7b6095b40b0a3dc024e0e055ed1
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : 0.23870155215263367
# COMET INFO:     optimizer_name         : Optimize My Network
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"batch_size": 64, "first_layer_units": 429, "k_r": "l2"}
# COMET INFO:     optimizer_pid          : d678f9aa4a4f69a3dfbed58ce9814b1ee04b83cb
# COMET INFO:     optimizer_process      : 26263
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.1.10
# COMET INFO:     trainable_params       : 260039
# COMET INFO:   Parameters:
# COMET INFO:     Adam_amsgrad                     : False
# COMET INFO:     Adam_beta_1                      : 0.9
# COMET INFO:     Adam_beta_2                      : 0.999
# COMET INFO:     Adam_clipnorm                    : None
# COMET INFO:     Adam_clipvalue                   : None
# COMET INFO:     Adam_ema_momentum                : 0.99
# COMET INFO:     Adam_ema_overwrite_frequency     : None
# COMET INFO:     Adam_epsilon                     : 1e-07
# COMET INFO:     Adam_global_clipnorm             : None
# COMET INFO:     Adam_gradient_accumulation_steps : None
# COMET INFO:     Adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     Adam_loss_scale_factor           : None
# COMET INFO:     Adam_name                        : adam
# COMET INFO:     Adam_use_ema                     : False
# COMET INFO:     Adam_weight_decay                : None
# COMET INFO:     Optimizer                        : adam
# COMET INFO:     adam_amsgrad                     : False
# COMET INFO:     adam_beta_1                      : 0.9
# COMET INFO:     adam_beta_2                      : 0.999
# COMET INFO:     adam_clipnorm                    : None
# COMET INFO:     adam_clipvalue                   : None
# COMET INFO:     adam_ema_momentum                : 0.99
# COMET INFO:     adam_ema_overwrite_frequency     : None
# COMET INFO:     adam_epsilon                     : 1e-07
# COMET INFO:     adam_global_clipnorm             : None
# COMET INFO:     adam_gradient_accumulation_steps : None
# COMET INFO:     adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     adam_loss_scale_factor           : None
# COMET INFO:     adam_use_ema                     : False
# COMET INFO:     adam_weight_decay                : None
# COMET INFO:     batch_size                       : 64
# COMET INFO:     epochs                           : 50
# COMET INFO:     first_layer_units                : 429
# COMET INFO:     k_r                              : l2
# COMET INFO:     steps                            : 125
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/mehdi-moha/general/9fbc9b5e26f543d5886d9293b010d468
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.7332 - loss: 5.6827 - val_accuracy: 0.9535 - val_loss: 1.5272
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9360 - loss: 1.2425 - val_accuracy: 0.9505 - val_loss: 0.6433
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9400 - loss: 0.6192 - val_accuracy: 0.9510 - val_loss: 0.4645
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9489 - loss: 0.4670 - val_accuracy: 0.9490 - val_loss: 0.4246
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9438 - loss: 0.4361 - val_accuracy: 0.9555 - val_loss: 0.3970
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9509 - loss: 0.3932 - val_accuracy: 0.9470 - val_loss: 0.3988
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9497 - loss: 0.3922 - val_accuracy: 0.9505 - val_loss: 0.3656
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9523 - loss: 0.3690 - val_accuracy: 0.9675 - val_loss: 0.3257
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9497 - loss: 0.3709 - val_accuracy: 0.9635 - val_loss: 0.3396
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9534 - loss: 0.3632 - val_accuracy: 0.9400 - val_loss: 0.3841
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9522 - loss: 0.3628 - val_accuracy: 0.9565 - val_loss: 0.3532
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9621 - loss: 0.3363 - val_accuracy: 0.9595 - val_loss: 0.3317
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9537 - loss: 0.3447 - val_accuracy: 0.9575 - val_loss: 0.3323
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9562 - loss: 0.3344 - val_accuracy: 0.9710 - val_loss: 0.2921
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9581 - loss: 0.3247 - val_accuracy: 0.9635 - val_loss: 0.3063
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9600 - loss: 0.3162 - val_accuracy: 0.9645 - val_loss: 0.3177
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9611 - loss: 0.3248 - val_accuracy: 0.9690 - val_loss: 0.2897
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9623 - loss: 0.3019 - val_accuracy: 0.9540 - val_loss: 0.3277
# Epoch 19/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9587 - loss: 0.3142 - val_accuracy: 0.9675 - val_loss: 0.2885
# Epoch 20/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9611 - loss: 0.3115 - val_accuracy: 0.9615 - val_loss: 0.2917
# Epoch 21/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [50]                 : (0.8588749766349792, 0.9711250066757202)
# COMET INFO:     batch_accuracy [650]          : (0.09375, 1.0)
# COMET INFO:     batch_loss [650]              : (0.17939671874046326, 9.304141998291016)
# COMET INFO:     epoch_duration [50]           : (1.6378398329998163, 4.251272254000014)
# COMET INFO:     loss [51]                     : (0.2406974583864212, 3.8423376083374023)
# COMET INFO:     test_accuracy                 : 0.965499997138977
# COMET INFO:     test_loss                     : 0.27502620220184326
# COMET INFO:     val_accuracy [50]             : (0.9399999976158142, 0.9760000109672546)
# COMET INFO:     val_loss [51]                 : (0.22358527779579163, 1.5271799564361572)
# COMET INFO:     validate_batch_accuracy [200] : (0.90625, 0.984375)
# COMET INFO:     validate_batch_loss [200]     : (0.21293458342552185, 1.551098108291626)
# COMET INFO:   Others:
# COMET INFO:     notebook_url           : https://colab.research.google.com/notebook#fileId=16rcyO1XAqsDI4NTJJPm63smWjtc_YnY3
# COMET INFO:     optimizer_count        : 10
# COMET INFO:     optimizer_id           : 2a5fe7b6095b40b0a3dc024e0e055ed1
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : 0.2406974583864212
# COMET INFO:     optimizer_name         : Optimize My Network
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"batch_size": 64, "first_layer_units": 429, "k_r": "l2"}
# COMET INFO:     optimizer_pid          : d678f9aa4a4f69a3dfbed58ce9814b1ee04b83cb
# COMET INFO:     optimizer_process      : 26263
# COMET INFO:     optimizer_trial        : 2
# COMET INFO:     optimizer_version      : 2.1.10
# COMET INFO:     trainable_params       : 260039
# COMET INFO:   Parameters:
# COMET INFO:     Adam_amsgrad                     : False
# COMET INFO:     Adam_beta_1                      : 0.9
# COMET INFO:     Adam_beta_2                      : 0.999
# COMET INFO:     Adam_clipnorm                    : None
# COMET INFO:     Adam_clipvalue                   : None
# COMET INFO:     Adam_ema_momentum                : 0.99
# COMET INFO:     Adam_ema_overwrite_frequency     : None
# COMET INFO:     Adam_epsilon                     : 1e-07
# COMET INFO:     Adam_global_clipnorm             : None
# COMET INFO:     Adam_gradient_accumulation_steps : None
# COMET INFO:     Adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     Adam_loss_scale_factor           : None
# COMET INFO:     Adam_name                        : adam
# COMET INFO:     Adam_use_ema                     : False
# COMET INFO:     Adam_weight_decay                : None
# COMET INFO:     Optimizer                        : adam
# COMET INFO:     adam_amsgrad                     : False
# COMET INFO:     adam_beta_1                      : 0.9
# COMET INFO:     adam_beta_2                      : 0.999
# COMET INFO:     adam_clipnorm                    : None
# COMET INFO:     adam_clipvalue                   : None
# COMET INFO:     adam_ema_momentum                : 0.99
# COMET INFO:     adam_ema_overwrite_frequency     : None
# COMET INFO:     adam_epsilon                     : 1e-07
# COMET INFO:     adam_global_clipnorm             : None
# COMET INFO:     adam_gradient_accumulation_steps : None
# COMET INFO:     adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     adam_loss_scale_factor           : None
# COMET INFO:     adam_use_ema                     : False
# COMET INFO:     adam_weight_decay                : None
# COMET INFO:     batch_size                       : 64
# COMET INFO:     epochs                           : 50
# COMET INFO:     first_layer_units                : 429
# COMET INFO:     k_r                              : l2
# COMET INFO:     steps                            : 125
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET INFO: Optimizer search 2a5fe7b6095b40b0a3dc024e0e055ed1 has completed
# Best Test Accuracy: 0.968999981880188
# Best Parameters: {'first_layer_units': 429, 'batch_size': 64, 'k_r': 'l2', 'epochs': 50}
