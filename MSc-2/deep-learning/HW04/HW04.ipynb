# %%
print("Installing comet_ml...")
# !pip install comet_ml --quiet
print("Installation complete!\n")

import comet_ml
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pathlib
import matplotlib.pyplot as plt

from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import SparseCategoricalCrossentropy

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU device: {tf.test.gpu_device_name()}")
print()

comet_ml.login()

optimizers_dict = {
    "adam": keras.optimizers.Adam(learning_rate=0.001),
    "rmsprop": keras.optimizers.RMSprop(learning_rate=0.001),
    "sgd": keras.optimizers.SGD(learning_rate=0.001, momentum=0.9),
    "nadam": keras.optimizers.Nadam(learning_rate=0.001),
    "adagrad": keras.optimizers.Adagrad(learning_rate=0.001)
}

print("Downloading flower photos dataset...")
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

archive_path = tf.keras.utils.get_file(
    origin=dataset_url,
    fname="flower_photos.tgz",
    extract=True
)

base_dir = pathlib.Path(archive_path).parent

data_dir = None
possible_paths = [
    base_dir / "flower_photos",
    pathlib.Path(str(base_dir).replace("/flower_photos", "")) / "flower_photos"
]

for path in possible_paths:
    if path.exists() and (path / "daisy").exists():
        data_dir = path
        break

if data_dir is None:
    all_subdirs = list(base_dir.rglob("daisy"))
    if all_subdirs:
        data_dir = all_subdirs[0].parent

if data_dir is None or not data_dir.exists():
    raise FileNotFoundError(f"Dataset directory not found. Searched in: {base_dir}")

print(f"Dataset path: {data_dir}")

subdirs = sorted([d.name for d in data_dir.iterdir() if d.is_dir()])
print(f"Subdirectories: {subdirs}")

total_images = 0
for subdir in subdirs:
    num_images = len(list((data_dir / subdir).glob("*.jpg")))
    total_images += num_images
    print(f"   - {subdir}: {num_images} images")
print(f"   Total: {total_images} images")
print()

BATCH_SIZE = 32
img_height = 180
img_width = 180

def get_dataset():
    train_ds = tf.keras.utils.image_dataset_from_directory(
        data_dir,
        validation_split=0.2,
        subset="training",
        seed=123,
        image_size=(img_height, img_width),
        batch_size=BATCH_SIZE
    )

    val_ds = tf.keras.utils.image_dataset_from_directory(
        data_dir,
        validation_split=0.2,
        subset="validation",
        seed=123,
        image_size=(img_height, img_width),
        batch_size=BATCH_SIZE
    )

    class_names = train_ds.class_names
    num_classes = len(class_names)

    print(f"Classes: {class_names}")
    print(f"Number of classes: {num_classes}")

    if num_classes != 5:
        raise ValueError(f"Expected 5 classes but found {num_classes}!")

    return train_ds, val_ds, class_names, num_classes

train_ds, val_ds, class_names, num_classes = get_dataset()
print()

data_augmentation = Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(height_factor=0.2, width_factor=0.2)
], name="data_augmentation")

def prepare_train(ds):
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y),
                num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.map(lambda x, y: (x / 255.0, y),
                num_parallel_calls=tf.data.AUTOTUNE)
    return ds

def prepare_val(ds):
    ds = ds.map(lambda x, y: (x / 255.0, y),
                num_parallel_calls=tf.data.AUTOTUNE)
    return ds

train_ds = prepare_train(train_ds)
val_ds = prepare_val(val_ds)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

print("Dataset preprocessing complete!")
print("   Training: with data augmentation + normalization")
print("   Validation: with normalization only (no augmentation)")
print()

print("Visualizing data augmentation examples...")

vis_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=BATCH_SIZE
)

plt.figure(figsize=(12, 12))

for images, labels in vis_ds.take(1):
    single_image = images[0:1] / 255.0
    class_name = class_names[labels[0].numpy()]

    for i in range(9):
        augmented = data_augmentation(single_image, training=True)

        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented[0])
        plt.axis('off')
        plt.title(f"Aug {i+1}", fontsize=10)

    plt.suptitle(f"Data Augmentation - {class_name.upper()}",
                 fontsize=16, fontweight='bold')
    break

plt.tight_layout()
plt.show()
print()

def build_model_graph(experiment):
    optz_name = experiment.get_parameter("optz")
    optimizer = optimizers_dict[optz_name]

    model = Sequential([
        layers.Input(shape=(img_height, img_width, 3)),

        layers.Conv2D(32, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(256, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(num_classes)
    ], name="flower_classifier")

    model.compile(
        optimizer=optimizer,
        loss=SparseCategoricalCrossentropy(from_logits=True),
        metrics=['accuracy']
    )

    return model

def train(experiment, model, train_ds, val_ds):
    epochs = experiment.get_parameter("epochs")

    early_stopping = keras.callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=7,
        restore_best_weights=True,
        mode='max'
    )

    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_lr=1e-7,
        verbose=1
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    return history

config = {
    "algorithm": "bayes",
    "name": "Optimize Flower Classifier",
    "spec": {
        "maxCombo": 5,
        "objective": "maximize",
        "metric": "val_accuracy"
    },
    "parameters": {
        "optz": {
            "type": "categorical",
            "values": ["adam", "rmsprop", "sgd", "nadam", "adagrad"]
        },
    },
    "trials": 1,
}

print("="*70)
print("Starting Comet ML Optimization")
print("="*70)
print()

opt = comet_ml.Optimizer(config, project_name="comet-optimizer")

for experiment in opt.get_experiments():
    experiment.log_parameter("epochs", 50)
    experiment.log_parameter("batch_size", BATCH_SIZE)
    experiment.log_parameter("img_height", img_height)
    experiment.log_parameter("img_width", img_width)
    experiment.log_parameter("num_classes", num_classes)
    experiment.log_other("class_names", class_names)

    optz_name = experiment.get_parameter("optz")

    print(f"\n{'='*70}")
    print(f"Experiment with optimizer: {optz_name.upper()}")
    print(f"{'='*70}\n")

    model = build_model_graph(experiment)
    model.summary()
    print()

    history = train(experiment, model, train_ds, val_ds)

    best_epoch = np.argmax(history.history['val_accuracy'])
    final_loss = history.history['loss'][best_epoch]
    final_acc = history.history['accuracy'][best_epoch]
    final_val_loss = history.history['val_loss'][best_epoch]
    final_val_acc = history.history['val_accuracy'][best_epoch]

    print(f"\n{'='*70}")
    print(f"Best Results (Epoch {best_epoch + 1}):")
    print(f"{'='*70}")
    print(f"   Training Loss:       {final_loss:.4f}")
    print(f"   Training Accuracy:   {final_acc*100:.2f}%")
    print(f"   Validation Loss:     {final_val_loss:.4f}")
    print(f"   Validation Accuracy: {final_val_acc*100:.2f}%")
    print(f"{'='*70}\n")

    experiment.end()

    print(f"Experiment with {optz_name} completed!\n")

print("="*70)
print("All optimization experiments complete!")
print("="*70)
print()

print("Testing model with custom image...")
img_path = "/content/flower.jpg"

try:
    img = tf.keras.utils.load_img(img_path, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)
    img_array = img_array / 255.0

    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])

    predicted_class = class_names[np.argmax(score)]
    confidence = 100 * np.max(score)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    ax1.imshow(img)
    ax1.axis('off')

    if confidence > 80:
        title_color = 'green'
    elif confidence > 60:
        title_color = 'orange'
    else:
        title_color = 'red'

    ax1.set_title(
        f"{predicted_class.upper()}\nConfidence: {confidence:.1f}%",
        fontsize=16,
        fontweight='bold',
        color=title_color
    )

    probs = [100 * score[i].numpy() for i in range(num_classes)]
    colors = ['#2ecc71' if i == np.argmax(score) else '#3498db' for i in range(num_classes)]

    bars = ax2.barh(class_names, probs, color=colors, edgecolor='black', linewidth=1.5)
    ax2.set_xlabel('Confidence (%)', fontsize=12, fontweight='bold')
    ax2.set_title('Class Probabilities', fontsize=14, fontweight='bold')
    ax2.set_xlim(0, 100)
    ax2.grid(axis='x', alpha=0.3, linestyle='--')

    for i, (bar, prob) in enumerate(zip(bars, probs)):
        ax2.text(prob + 2, i, f'{prob:.1f}%', va='center', fontsize=11, fontweight='bold')

    plt.tight_layout()
    plt.show()

    print(f"\n{'='*70}")
    print(f"PREDICTION RESULT")
    print(f"{'='*70}")
    print(f"Class:      {predicted_class.upper()}")
    print(f"Confidence: {confidence:.2f}%")
    print(f"Status:     {'High confidence' if confidence > 70 else 'Low confidence'}")
    print(f"{'='*70}\n")

    print("Detailed class probabilities:")
    print("-" * 70)
    sorted_indices = np.argsort(probs)[::-1]
    for rank, idx in enumerate(sorted_indices, 1):
        name = class_names[idx]
        prob = probs[idx]
        bar_length = int(prob / 2)
        bar = '=' * bar_length
        marker = ' <- PREDICTED' if idx == np.argmax(score) else ''
        print(f"{rank}. {name:15s}: {prob:5.1f}% {bar}{marker}")
    print("-" * 70)

except FileNotFoundError:
    print(f"\nError: Image not found at {img_path}\n")
    print("=" * 70)
    print("HOW TO FIX:")
    print("=" * 70)
    print("Option 1: Upload your own flower image to /content/flower.jpg")
    print()
    print("Option 2: Download a sample image")
    print("Run this code:")
    print("!wget -O /content/flower.jpg https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos/roses/2414954629_3708a1a04d.jpg")
    print("=" * 70)

except Exception as e:
    print(f"\nError: {e}")
    import traceback
    traceback.print_exc()

print("\n" + "="*70)
print("ALL TASKS COMPLETED!")
print("="*70)
# Out:
# Installing comet_ml...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.9/780.9 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.4 MB/s eta 0:00:00
# Installation complete!
#
# TensorFlow version: 2.19.0
# GPU device: /device:GPU:0
#
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).
# Downloading flower photos dataset...
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228813984/228813984 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Dataset path: /root/.keras/datasets/flower_photos_extracted/flower_photos
# Subdirectories: ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
#    - daisy: 633 images
#    - dandelion: 898 images
#    - roses: 641 images
#    - sunflowers: 699 images
#    - tulips: 799 images
#    Total: 3670 images
#
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.
# Classes: ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
# Number of classes: 5
#
# Dataset preprocessing complete!
#    Training: with data augmentation + normalization
#    Validation: with normalization only (no augmentation)
#
# Visualizing data augmentation examples...
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# COMET WARNING: Passing Experiment through Optimizer constructor is deprecated; pass them to Optimizer.get_experiments or Optimizer.next
# ======================================================================
# Starting Comet ML Optimization
# ======================================================================
# COMET INFO: 4f517a9ca85c4039a0686bf8eef00490
# COMET INFO: Using optimizer config: {'algorithm': 'bayes', 'configSpaceSize': 5, 'endTime': None, 'id': '4f517a9ca85c4039a0686bf8eef00490', 'lastUpdateTime': None, 'maxCombo': 5, 'name': 'Optimize Flower Classifier', 'parameters': {'optz': {'type': 'categorical', 'values': ['adam', 'rmsprop', 'sgd', 'nadam', 'adagrad']}}, 'predictor': None, 'spec': {'gridSize': 10, 'maxCombo': 5, 'metric': 'val_accuracy', 'minSampleSize': 100, 'objective': 'maximize', 'retryAssignLimit': 0, 'retryLimit': 1000}, 'startTime': 185970700, 'state': {'mode': None, 'seed': None, 'sequence': [], 'sequence_i': 0, 'sequence_pid': None, 'sequence_retry': 0, 'sequence_retry_count': 0}, 'status': 'running', 'suggestion_count': 0, 'trials': 1, 'version': '2.1.10'}
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/mehdi-moha/comet-optimizer/3f4b478096cc406785cc54fdea7f3f4b
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# ======================================================================
# Experiment with optimizer: RMSPROP
# ======================================================================
# Model: "flower_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 178, 178, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 87, 87, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 41, 41, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 18, 18, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 20736)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    10,617,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,140,293 (42.50 MB)
#  Trainable params: 11,139,333 (42.49 MB)
#  Non-trainable params: 960 (3.75 KB)
# COMET WARNING: tensorflow datasets are not currently supported for gradient and activation auto-logging
# COMET INFO: Ignoring automatic log_parameter('verbose') because 'keras:verbose' is in COMET_LOGGING_PARAMETERS_IGNORE
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 48s 152ms/step - accuracy: 0.3207 - loss: 13.1912 - val_accuracy: 0.2670 - val_loss: 3.8170 - learning_rate: 0.0010
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.3684 - loss: 4.2247 - val_accuracy: 0.2807 - val_loss: 1.5752 - learning_rate: 0.0010
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.4141 - loss: 2.3085 - val_accuracy: 0.3447 - val_loss: 1.5009 - learning_rate: 0.0010
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.4220 - loss: 1.7383 - val_accuracy: 0.3937 - val_loss: 1.5311 - learning_rate: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.4608 - loss: 1.5288 - val_accuracy: 0.4619 - val_loss: 1.3449 - learning_rate: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.4666 - loss: 1.4503 - val_accuracy: 0.5586 - val_loss: 1.1213 - learning_rate: 0.0010
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.5146 - loss: 1.3583 - val_accuracy: 0.5245 - val_loss: 1.2997 - learning_rate: 0.0010
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.5327 - loss: 1.3535 - val_accuracy: 0.5463 - val_loss: 1.1581 - learning_rate: 0.0010
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.5635 - loss: 1.2688 - val_accuracy: 0.5913 - val_loss: 1.0259 - learning_rate: 0.0010
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.5798 - loss: 1.1805 - val_accuracy: 0.5232 - val_loss: 1.0730 - learning_rate: 0.0010
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.5942 - loss: 1.0882 - val_accuracy: 0.6390 - val_loss: 0.9559 - learning_rate: 0.0010
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5856 - loss: 1.1279 - val_accuracy: 0.5232 - val_loss: 1.1175 - learning_rate: 0.0010
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.6284 - loss: 1.0311 - val_accuracy: 0.6431 - val_loss: 0.9097 - learning_rate: 0.0010
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.6517 - loss: 0.9727 - val_accuracy: 0.6335 - val_loss: 0.9593 - learning_rate: 0.0010
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.6462 - loss: 0.9288 - val_accuracy: 0.5518 - val_loss: 1.3842 - learning_rate: 0.0010
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6656 - loss: 0.9390
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.6656 - loss: 0.9390 - val_accuracy: 0.5899 - val_loss: 1.0357 - learning_rate: 0.0010
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.7141 - loss: 0.7624 - val_accuracy: 0.6989 - val_loss: 0.8358 - learning_rate: 5.0000e-04
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.7350 - loss: 0.6980 - val_accuracy: 0.6962 - val_loss: 0.8494 - learning_rate: 5.0000e-04
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.7429 - loss: 0.6825 - val_accuracy: 0.6880 - val_loss: 0.9785 - learning_rate: 5.0000e-04
# Epoch 20/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7871 - loss: 0.5577
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.7869 - loss: 0.5584 - val_accuracy: 0.6812 - val_loss: 0.9623 - learning_rate: 5.0000e-04
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.8199 - loss: 0.4938 - val_accuracy: 0.6935 - val_loss: 0.9959 - learning_rate: 2.5000e-04
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.8358 - loss: 0.4217 - val_accuracy: 0.7084 - val_loss: 0.9393 - learning_rate: 2.5000e-04
# Epoch 23/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8539 - loss: 0.3823
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.8538 - loss: 0.3828 - val_accuracy: 0.6935 - val_loss: 1.1638 - learning_rate: 2.5000e-04
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.8784 - loss: 0.3360 - val_accuracy: 0.7275 - val_loss: 1.0476 - learning_rate: 1.2500e-04
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.8848 - loss: 0.2811 - val_accuracy: 0.7166 - val_loss: 1.0447 - learning_rate: 1.2500e-04
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8766 - loss: 0.3074
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.8766 - loss: 0.3074 - val_accuracy: 0.7125 - val_loss: 1.1180 - learning_rate: 1.2500e-04
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9054 - loss: 0.2770 - val_accuracy: 0.7248 - val_loss: 1.1829 - learning_rate: 6.2500e-05
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.8955 - loss: 0.2457 - val_accuracy: 0.7153 - val_loss: 1.2458 - learning_rate: 6.2500e-05
# Epoch 29/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9027 - loss: 0.2424
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9028 - loss: 0.2422 - val_accuracy: 0.7139 - val_loss: 1.2909 - learning_rate: 6.2500e-05
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.8986 - loss: 0.2431 - val_accuracy: 0.7234 - val_loss: 1.2625 - learning_rate: 3.1250e-05
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.9184 - loss: 0.2211 - val_accuracy: 0.7207 - val_loss: 1.2739 - learning_rate: 3.1250e-05
#
# ======================================================================
# Best Results (Epoch 24):
# ======================================================================
#    Training Loss:       0.3387
#    Training Accuracy:   87.43%
#    Validation Loss:     1.0476
#    Validation Accuracy: 72.75%
# ======================================================================
# COMET WARNING: Couldn't retrieve and log Google Colab notebook content, reason: 'NoneType' object is not subscriptable
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : evident_cornice_2748
# COMET INFO:     url                   : https://www.comet.com/mehdi-moha/comet-optimizer/3f4b478096cc406785cc54fdea7f3f4b
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [31]                : (0.34502723813056946, 0.9199591279029846)
# COMET INFO:     batch_accuracy [310]         : (0.15625, 0.96875)
# COMET INFO:     batch_loss [310]             : (0.1272890865802765, 18.401390075683594)
# COMET INFO:     epoch_duration [31]          : (4.185262986999987, 48.467743480999985)
# COMET INFO:     learning_rate [31]           : (3.125000148429535e-05, 0.0010000000474974513)
# COMET INFO:     loss [31]                    : (0.21177616715431213, 9.479612350463867)
# COMET INFO:     val_accuracy [31]            : (0.2670299708843231, 0.7275204062461853)
# COMET INFO:     val_loss [31]                : (0.8358009457588196, 3.8170459270477295)
# COMET INFO:     validate_batch_accuracy [93] : (0.21875, 0.75)
# COMET INFO:     validate_batch_loss [93]     : (0.8279997706413269, 4.00621223449707)
# COMET INFO:   Others:
# COMET INFO:     class_names            : ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
# COMET INFO:     notebook_url           : https://colab.research.google.com/notebook#fileId=19aPZJGPr4CqvQAZjbetPP1DehjozvW4T
# COMET INFO:     optimizer_count        : 1
# COMET INFO:     optimizer_id           : 4f517a9ca85c4039a0686bf8eef00490
# COMET INFO:     optimizer_metric       : val_accuracy
# COMET INFO:     optimizer_metric_value : 0.7275204062461853
# COMET INFO:     optimizer_name         : Optimize Flower Classifier
# COMET INFO:     optimizer_objective    : maximize
# COMET INFO:     optimizer_parameters   : {"optz": "rmsprop"}
# COMET INFO:     optimizer_pid          : 130249d503d10411c06a8536be1fb088fbca3a42
# COMET INFO:     optimizer_process      : 247
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.1.10
# COMET INFO:     trainable_params       : 11140293
# COMET INFO:   Parameters:
# COMET INFO:     RMSprop_centered                    : False
# COMET INFO:     RMSprop_clipnorm                    : None
# COMET INFO:     RMSprop_clipvalue                   : None
# COMET INFO:     RMSprop_ema_momentum                : 0.99
# COMET INFO:     RMSprop_ema_overwrite_frequency     : None
# COMET INFO:     RMSprop_epsilon                     : 1e-07
# COMET INFO:     RMSprop_global_clipnorm             : None
# COMET INFO:     RMSprop_gradient_accumulation_steps : None
# COMET INFO:     RMSprop_learning_rate               : 0.0010000000474974513
# COMET INFO:     RMSprop_loss_scale_factor           : None
# COMET INFO:     RMSprop_momentum                    : 0.0
# COMET INFO:     RMSprop_name                        : rmsprop
# COMET INFO:     RMSprop_rho                         : 0.9
# COMET INFO:     RMSprop_use_ema                     : False
# COMET INFO:     RMSprop_weight_decay                : None
# COMET INFO:     batch_size                          : 32
# COMET INFO:     epochs                              : 50
# COMET INFO:     img_height                          : 180
# COMET INFO:     img_width                           : 180
# COMET INFO:     num_classes                         : 5
# COMET INFO:     optz                                : rmsprop
# COMET INFO:     steps                               : 92
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# Experiment with rmsprop completed!
# COMET INFO: Experiment is live on comet.com https://www.comet.com/mehdi-moha/comet-optimizer/12794105eb8c4682b6e4a00b0c76423b
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# ======================================================================
# Experiment with optimizer: NADAM
# ======================================================================
# Model: "flower_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 178, 178, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 87, 87, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 41, 41, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 18, 18, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 20736)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │    10,617,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,140,293 (42.50 MB)
#  Trainable params: 11,139,333 (42.49 MB)
#  Non-trainable params: 960 (3.75 KB)
# COMET WARNING: tensorflow datasets are not currently supported for gradient and activation auto-logging
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 108ms/step - accuracy: 0.3602 - loss: 6.2701 - val_accuracy: 0.2398 - val_loss: 2.1288 - learning_rate: 0.0010
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.4184 - loss: 2.7736 - val_accuracy: 0.2357 - val_loss: 1.9351 - learning_rate: 0.0010
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.4044 - loss: 1.9454 - val_accuracy: 0.2439 - val_loss: 1.6944 - learning_rate: 0.0010
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.4624 - loss: 1.5703 - val_accuracy: 0.3529 - val_loss: 1.4437 - learning_rate: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.5030 - loss: 1.3425 - val_accuracy: 0.4755 - val_loss: 1.3248 - learning_rate: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.5127 - loss: 1.1926 - val_accuracy: 0.5041 - val_loss: 1.1380 - learning_rate: 0.0010
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.5821 - loss: 1.0852 - val_accuracy: 0.5845 - val_loss: 1.0397 - learning_rate: 0.0010
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.6238 - loss: 1.0221 - val_accuracy: 0.4619 - val_loss: 1.3107 - learning_rate: 0.0010
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.6204 - loss: 0.9822 - val_accuracy: 0.6076 - val_loss: 0.9988 - learning_rate: 0.0010
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.6518 - loss: 0.9285 - val_accuracy: 0.6281 - val_loss: 0.9790 - learning_rate: 0.0010
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.6704 - loss: 0.8835 - val_accuracy: 0.6662 - val_loss: 0.8616 - learning_rate: 0.0010
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.6904 - loss: 0.8055 - val_accuracy: 0.6117 - val_loss: 1.0675 - learning_rate: 0.0010
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.6868 - loss: 0.8316 - val_accuracy: 0.7044 - val_loss: 0.8293 - learning_rate: 0.0010
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.7080 - loss: 0.7498 - val_accuracy: 0.6485 - val_loss: 1.0314 - learning_rate: 0.0010
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.7369 - loss: 0.7017 - val_accuracy: 0.6526 - val_loss: 0.9234 - learning_rate: 0.0010
# Epoch 16/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7266 - loss: 0.7114
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.7266 - loss: 0.7113 - val_accuracy: 0.6090 - val_loss: 1.0711 - learning_rate: 0.0010
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.7547 - loss: 0.6153 - val_accuracy: 0.7098 - val_loss: 0.7909 - learning_rate: 5.0000e-04
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.8213 - loss: 0.4817 - val_accuracy: 0.7153 - val_loss: 0.8488 - learning_rate: 5.0000e-04
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.8099 - loss: 0.4630 - val_accuracy: 0.7030 - val_loss: 0.8950 - learning_rate: 5.0000e-04
# Epoch 20/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8488 - loss: 0.4112
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.8487 - loss: 0.4113 - val_accuracy: 0.7275 - val_loss: 0.8122 - learning_rate: 5.0000e-04
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.8604 - loss: 0.3385 - val_accuracy: 0.7534 - val_loss: 0.7364 - learning_rate: 2.5000e-04
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.8884 - loss: 0.2767 - val_accuracy: 0.7439 - val_loss: 0.7689 - learning_rate: 2.5000e-04
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.8982 - loss: 0.2719 - val_accuracy: 0.7289 - val_loss: 0.8533 - learning_rate: 2.5000e-04
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9127 - loss: 0.2359
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9127 - loss: 0.2359 - val_accuracy: 0.7398 - val_loss: 0.7986 - learning_rate: 2.5000e-04
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9265 - loss: 0.2027 - val_accuracy: 0.7480 - val_loss: 0.8023 - learning_rate: 1.2500e-04
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9355 - loss: 0.1804 - val_accuracy: 0.7534 - val_loss: 0.8363 - learning_rate: 1.2500e-04
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9465 - loss: 0.1516
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9464 - loss: 0.1517 - val_accuracy: 0.7507 - val_loss: 0.8207 - learning_rate: 1.2500e-04
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9405 - loss: 0.1613 - val_accuracy: 0.7575 - val_loss: 0.8134 - learning_rate: 6.2500e-05
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9566 - loss: 0.1348 - val_accuracy: 0.7493 - val_loss: 0.8383 - learning_rate: 6.2500e-05
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9654 - loss: 0.1120
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9654 - loss: 0.1120 - val_accuracy: 0.7493 - val_loss: 0.8467 - learning_rate: 6.2500e-05
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9545 - loss: 0.1260 - val_accuracy: 0.7561 - val_loss: 0.8539 - learning_rate: 3.1250e-05
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9692 - loss: 0.1033 - val_accuracy: 0.7629 - val_loss: 0.8475 - learning_rate: 3.1250e-05
# Epoch 33/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9710 - loss: 0.1041
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9709 - loss: 0.1041 - val_accuracy: 0.7520 - val_loss: 0.8595 - learning_rate: 3.1250e-05
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9652 - loss: 0.1116 - val_accuracy: 0.7548 - val_loss: 0.8614 - learning_rate: 1.5625e-05
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9684 - loss: 0.1018 - val_accuracy: 0.7561 - val_loss: 0.8634 - learning_rate: 1.5625e-05
# Epoch 36/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9663 - loss: 0.0944
# Epoch 36: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9664 - loss: 0.0944 - val_accuracy: 0.7602 - val_loss: 0.8613 - learning_rate: 1.5625e-05
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9684 - loss: 0.0992 - val_accuracy: 0.7616 - val_loss: 0.8595 - learning_rate: 7.8125e-06
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9725 - loss: 0.0871 - val_accuracy: 0.7616 - val_loss: 0.8672 - learning_rate: 7.8125e-06
# Epoch 39/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9656 - loss: 0.1045
# Epoch 39: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9657 - loss: 0.1044 - val_accuracy: 0.7616 - val_loss: 0.8724 - learning_rate: 7.8125e-06
#
# ======================================================================
# Best Results (Epoch 32):
# ======================================================================
#    Training Loss:       0.1084
#    Training Accuracy:   96.90%
#    Validation Loss:     0.8475
#    Validation Accuracy: 76.29%
# ======================================================================
# COMET WARNING: Couldn't retrieve and log Google Colab notebook content, reason: 'NoneType' object is not subscriptable
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : dull_guppy_2520
# COMET INFO:     url                   : https://www.comet.com/mehdi-moha/comet-optimizer/12794105eb8c4682b6e4a00b0c76423b
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [39]                 : (0.3685286045074463, 0.9717302322387695)
# COMET INFO:     batch_accuracy [390]          : (0.25, 1.0)
# COMET INFO:     batch_loss [390]              : (0.05771800875663757, 7.760568141937256)
# COMET INFO:     epoch_duration [39]           : (4.297111885999982, 18.295996323999987)
# COMET INFO:     learning_rate [39]            : (7.812500371073838e-06, 0.0010000000474974513)
# COMET INFO:     loss [39]                     : (0.09068279713392258, 5.1951494216918945)
# COMET INFO:     val_accuracy [39]             : (0.23569482564926147, 0.7629427909851074)
# COMET INFO:     val_loss [39]                 : (0.7363908886909485, 2.1288294792175293)
# COMET INFO:     validate_batch_accuracy [117] : (0.21022728085517883, 0.8125)
# COMET INFO:     validate_batch_loss [117]     : (0.5420047640800476, 2.1490750312805176)
# COMET INFO:   Others:
# COMET INFO:     class_names            : ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
# COMET INFO:     notebook_url           : https://colab.research.google.com/notebook#fileId=19aPZJGPr4CqvQAZjbetPP1DehjozvW4T
# COMET INFO:     optimizer_count        : 2
# COMET INFO:     optimizer_id           : 4f517a9ca85c4039a0686bf8eef00490
# COMET INFO:     optimizer_metric       : val_accuracy
# COMET INFO:     optimizer_metric_value : 0.7629427909851074
# COMET INFO:     optimizer_name         : Optimize Flower Classifier
# COMET INFO:     optimizer_objective    : maximize
# COMET INFO:     optimizer_parameters   : {"optz": "nadam"}
# COMET INFO:     optimizer_pid          : 035cbc9ab3c10dee456e9d57dbc2757662281ca1
# COMET INFO:     optimizer_process      : 247
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.1.10
# COMET INFO:     trainable_params       : 11140293
# COMET INFO:   Parameters:
# COMET INFO:     Nadam_beta_1                      : 0.9
# COMET INFO:     Nadam_beta_2                      : 0.999
# COMET INFO:     Nadam_clipnorm                    : None
# COMET INFO:     Nadam_clipvalue                   : None
# COMET INFO:     Nadam_ema_momentum                : 0.99
# COMET INFO:     Nadam_ema_overwrite_frequency     : None
# COMET INFO:     Nadam_epsilon                     : 1e-07
# COMET INFO:     Nadam_global_clipnorm             : None
# COMET INFO:     Nadam_gradient_accumulation_steps : None
# COMET INFO:     Nadam_learning_rate               : 0.0010000000474974513
# COMET INFO:     Nadam_loss_scale_factor           : None
# COMET INFO:     Nadam_name                        : nadam
# COMET INFO:     Nadam_use_ema                     : False
# COMET INFO:     Nadam_weight_decay                : None
# COMET INFO:     batch_size                        : 32
# COMET INFO:     epochs                            : 50
# COMET INFO:     img_height                        : 180
# COMET INFO:     img_width                         : 180
# COMET INFO:     num_classes                       : 5
# COMET INFO:     optz                              : nadam
# COMET INFO:     steps                             : 92
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# Experiment with nadam completed!
# COMET INFO: Experiment is live on comet.com https://www.comet.com/mehdi-moha/comet-optimizer/e8fce71c09704ea39376446296d4f781
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# ======================================================================
# Experiment with optimizer: SGD
# ======================================================================
# Model: "flower_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 178, 178, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 87, 87, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 41, 41, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 18, 18, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 20736)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │    10,617,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,140,293 (42.50 MB)
#  Trainable params: 11,139,333 (42.49 MB)
#  Non-trainable params: 960 (3.75 KB)
# COMET WARNING: tensorflow datasets are not currently supported for gradient and activation auto-logging
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.3604 - loss: 2.1994 - val_accuracy: 0.2398 - val_loss: 3.8811 - learning_rate: 0.0010
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.5269 - loss: 1.2889 - val_accuracy: 0.2398 - val_loss: 3.6742 - learning_rate: 0.0010
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.5508 - loss: 1.1672 - val_accuracy: 0.3093 - val_loss: 1.9788 - learning_rate: 0.0010
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.5713 - loss: 1.1102 - val_accuracy: 0.4005 - val_loss: 1.6240 - learning_rate: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.6417 - loss: 0.9193 - val_accuracy: 0.5804 - val_loss: 1.1223 - learning_rate: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.6693 - loss: 0.8728 - val_accuracy: 0.6362 - val_loss: 0.9347 - learning_rate: 0.0010
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.7083 - loss: 0.7670 - val_accuracy: 0.6540 - val_loss: 0.9194 - learning_rate: 0.0010
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.7509 - loss: 0.6667 - val_accuracy: 0.6390 - val_loss: 0.9712 - learning_rate: 0.0010
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.7773 - loss: 0.5912 - val_accuracy: 0.6417 - val_loss: 0.9820 - learning_rate: 0.0010
# Epoch 10/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7921 - loss: 0.5613
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.7920 - loss: 0.5615 - val_accuracy: 0.6267 - val_loss: 0.9987 - learning_rate: 0.0010
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.8306 - loss: 0.4834 - val_accuracy: 0.6730 - val_loss: 0.9131 - learning_rate: 5.0000e-04
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.8696 - loss: 0.3907 - val_accuracy: 0.6826 - val_loss: 0.9351 - learning_rate: 5.0000e-04
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.8700 - loss: 0.3592 - val_accuracy: 0.6771 - val_loss: 0.9628 - learning_rate: 5.0000e-04
# Epoch 14/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8945 - loss: 0.3087
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.8945 - loss: 0.3087 - val_accuracy: 0.6948 - val_loss: 0.9463 - learning_rate: 5.0000e-04
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9114 - loss: 0.2736 - val_accuracy: 0.6866 - val_loss: 0.9594 - learning_rate: 2.5000e-04
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9237 - loss: 0.2424 - val_accuracy: 0.6853 - val_loss: 0.9546 - learning_rate: 2.5000e-04
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9225 - loss: 0.2283
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9225 - loss: 0.2281 - val_accuracy: 0.6962 - val_loss: 0.9737 - learning_rate: 2.5000e-04
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9369 - loss: 0.2032 - val_accuracy: 0.6975 - val_loss: 0.9518 - learning_rate: 1.2500e-04
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9427 - loss: 0.1869 - val_accuracy: 0.6935 - val_loss: 0.9859 - learning_rate: 1.2500e-04
# Epoch 20/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9497 - loss: 0.1756
# Epoch 20: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9498 - loss: 0.1756 - val_accuracy: 0.6907 - val_loss: 0.9852 - learning_rate: 1.2500e-04
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9520 - loss: 0.1749 - val_accuracy: 0.6962 - val_loss: 1.0043 - learning_rate: 6.2500e-05
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9507 - loss: 0.1821 - val_accuracy: 0.6921 - val_loss: 0.9964 - learning_rate: 6.2500e-05
# Epoch 23/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9500 - loss: 0.1683
# Epoch 23: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9500 - loss: 0.1682 - val_accuracy: 0.6975 - val_loss: 1.0109 - learning_rate: 6.2500e-05
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9579 - loss: 0.1599 - val_accuracy: 0.7030 - val_loss: 1.0155 - learning_rate: 3.1250e-05
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9562 - loss: 0.1562 - val_accuracy: 0.7044 - val_loss: 1.0080 - learning_rate: 3.1250e-05
# Epoch 26/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9575 - loss: 0.1469
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9575 - loss: 0.1470 - val_accuracy: 0.6962 - val_loss: 1.0095 - learning_rate: 3.1250e-05
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9667 - loss: 0.1483 - val_accuracy: 0.6989 - val_loss: 1.0142 - learning_rate: 1.5625e-05
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9522 - loss: 0.1623 - val_accuracy: 0.6989 - val_loss: 1.0153 - learning_rate: 1.5625e-05
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9600 - loss: 0.1557
# Epoch 29: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9600 - loss: 0.1557 - val_accuracy: 0.6975 - val_loss: 1.0133 - learning_rate: 1.5625e-05
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9589 - loss: 0.1548 - val_accuracy: 0.6962 - val_loss: 1.0138 - learning_rate: 7.8125e-06
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9609 - loss: 0.1397 - val_accuracy: 0.6962 - val_loss: 1.0142 - learning_rate: 7.8125e-06
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9471 - loss: 0.1712
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9472 - loss: 0.1711 - val_accuracy: 0.6962 - val_loss: 1.0143 - learning_rate: 7.8125e-06
#
# ======================================================================
# Best Results (Epoch 25):
# ======================================================================
#    Training Loss:       0.1600
#    Training Accuracy:   95.64%
#    Validation Loss:     1.0080
#    Validation Accuracy: 70.44%
# ======================================================================
# COMET WARNING: Couldn't retrieve and log Google Colab notebook content, reason: 'NoneType' object is not subscriptable
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : distant_bracket_5435
# COMET INFO:     url                   : https://www.comet.com/mehdi-moha/comet-optimizer/e8fce71c09704ea39376446296d4f781
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [32]                : (0.40497276186943054, 0.9645776748657227)
# COMET INFO:     batch_accuracy [320]         : (0.1875, 1.0)
# COMET INFO:     batch_loss [320]             : (0.03332032635807991, 3.7109246253967285)
# COMET INFO:     epoch_duration [32]          : (4.223136748999991, 14.35594588999993)
# COMET INFO:     learning_rate [32]           : (7.812500371073838e-06, 0.0010000000474974513)
# COMET INFO:     loss [32]                    : (0.14570939540863037, 1.8425744771957397)
# COMET INFO:     val_accuracy [32]            : (0.23978202044963837, 0.7043596506118774)
# COMET INFO:     val_loss [32]                : (0.9130890965461731, 3.8811028003692627)
# COMET INFO:     validate_batch_accuracy [96] : (0.21875, 0.8125)
# COMET INFO:     validate_batch_loss [96]     : (0.5502240657806396, 4.025468826293945)
# COMET INFO:   Others:
# COMET INFO:     class_names            : ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
# COMET INFO:     notebook_url           : https://colab.research.google.com/notebook#fileId=19aPZJGPr4CqvQAZjbetPP1DehjozvW4T
# COMET INFO:     optimizer_count        : 3
# COMET INFO:     optimizer_id           : 4f517a9ca85c4039a0686bf8eef00490
# COMET INFO:     optimizer_metric       : val_accuracy
# COMET INFO:     optimizer_metric_value : 0.7043596506118774
# COMET INFO:     optimizer_name         : Optimize Flower Classifier
# COMET INFO:     optimizer_objective    : maximize
# COMET INFO:     optimizer_parameters   : {"optz": "sgd"}
# COMET INFO:     optimizer_pid          : bbee6e2d8239b8601fc38f95039b36ec83615d7b
# COMET INFO:     optimizer_process      : 247
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.1.10
# COMET INFO:     trainable_params       : 11140293
# COMET INFO:   Parameters:
# COMET INFO:     SGD_clipnorm                    : None
# COMET INFO:     SGD_clipvalue                   : None
# COMET INFO:     SGD_ema_momentum                : 0.99
# COMET INFO:     SGD_ema_overwrite_frequency     : None
# COMET INFO:     SGD_global_clipnorm             : None
# COMET INFO:     SGD_gradient_accumulation_steps : None
# COMET INFO:     SGD_learning_rate               : 0.0010000000474974513
# COMET INFO:     SGD_loss_scale_factor           : None
# COMET INFO:     SGD_momentum                    : 0.9
# COMET INFO:     SGD_name                        : SGD
# COMET INFO:     SGD_nesterov                    : False
# COMET INFO:     SGD_use_ema                     : False
# COMET INFO:     SGD_weight_decay                : None
# COMET INFO:     batch_size                      : 32
# COMET INFO:     epochs                          : 50
# COMET INFO:     img_height                      : 180
# COMET INFO:     img_width                       : 180
# COMET INFO:     num_classes                     : 5
# COMET INFO:     optz                            : sgd
# COMET INFO:     steps                           : 92
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# Experiment with sgd completed!
# COMET INFO: Experiment is live on comet.com https://www.comet.com/mehdi-moha/comet-optimizer/6897f85def704acc83a54db97a850ad8
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# ======================================================================
# Experiment with optimizer: ADAGRAD
# ======================================================================
# Model: "flower_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ...
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 87, 87, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 41, 41, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 18, 18, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 20736)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 512)            │    10,617,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,140,293 (42.50 MB)
#  Trainable params: 11,139,333 (42.49 MB)
#  Non-trainable params: 960 (3.75 KB)
# COMET WARNING: tensorflow datasets are not currently supported for gradient and activation auto-logging
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 104ms/step - accuracy: 0.3262 - loss: 7.0768 - val_accuracy: 0.2997 - val_loss: 1.5690 - learning_rate: 0.0010
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.3516 - loss: 2.9495 - val_accuracy: 0.2943 - val_loss: 1.6451 - learning_rate: 0.0010
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.4055 - loss: 1.7529 - val_accuracy: 0.2847 - val_loss: 1.7712 - learning_rate: 0.0010
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.4649 - loss: 1.4215 - val_accuracy: 0.3910 - val_loss: 1.3994 - learning_rate: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.4942 - loss: 1.2977 - val_accuracy: 0.4687 - val_loss: 1.2398 - learning_rate: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.5130 - loss: 1.2241 - val_accuracy: 0.5177 - val_loss: 1.1222 - learning_rate: 0.0010
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.5506 - loss: 1.1787 - val_accuracy: 0.4837 - val_loss: 1.2138 - learning_rate: 0.0010
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.5749 - loss: 1.0530 - val_accuracy: 0.6076 - val_loss: 1.0224 - learning_rate: 0.0010
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.5952 - loss: 1.0157 - val_accuracy: 0.5177 - val_loss: 1.2502 - learning_rate: 0.0010
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.6006 - loss: 0.9990 - val_accuracy: 0.6553 - val_loss: 0.9994 - learning_rate: 0.0010
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.6220 - loss: 0.9356 - val_accuracy: 0.5940 - val_loss: 1.0719 - learning_rate: 0.0010
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.6486 - loss: 0.9176 - val_accuracy: 0.6444 - val_loss: 0.9275 - learning_rate: 0.0010
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.6518 - loss: 0.8992 - val_accuracy: 0.5300 - val_loss: 1.1021 - learning_rate: 0.0010
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.6613 - loss: 0.8837 - val_accuracy: 0.5668 - val_loss: 1.2700 - learning_rate: 0.0010
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.6984 - loss: 0.7763 - val_accuracy: 0.6771 - val_loss: 0.8728 - learning_rate: 0.0010
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.7159 - loss: 0.7819 - val_accuracy: 0.6635 - val_loss: 0.9381 - learning_rate: 0.0010
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.7301 - loss: 0.7058 - val_accuracy: 0.5954 - val_loss: 1.2804 - learning_rate: 0.0010
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7420 - loss: 0.6590
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.7420 - loss: 0.6592 - val_accuracy: 0.6144 - val_loss: 1.2085 - learning_rate: 0.0010
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.7640 - loss: 0.5834 - val_accuracy: 0.6962 - val_loss: 0.7847 - learning_rate: 5.0000e-04
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.8169 - loss: 0.4591 - val_accuracy: 0.6567 - val_loss: 1.1119 - learning_rate: 5.0000e-04
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.8364 - loss: 0.4131 - val_accuracy: 0.6962 - val_loss: 0.9192 - learning_rate: 5.0000e-04
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8463 - loss: 0.3702
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.8464 - loss: 0.3702 - val_accuracy: 0.7030 - val_loss: 0.9773 - learning_rate: 5.0000e-04
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.8883 - loss: 0.3021 - val_accuracy: 0.7057 - val_loss: 0.9236 - learning_rate: 2.5000e-04
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.8982 - loss: 0.2676 - val_accuracy: 0.6989 - val_loss: 1.1072 - learning_rate: 2.5000e-04
# Epoch 25/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9240 - loss: 0.2086
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9239 - loss: 0.2088 - val_accuracy: 0.7139 - val_loss: 1.0025 - learning_rate: 2.5000e-04
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9242 - loss: 0.2059 - val_accuracy: 0.7016 - val_loss: 1.0924 - learning_rate: 1.2500e-04
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9422 - loss: 0.1680 - val_accuracy: 0.7112 - val_loss: 1.0964 - learning_rate: 1.2500e-04
# Epoch 28/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9464 - loss: 0.1486
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9465 - loss: 0.1485 - val_accuracy: 0.7248 - val_loss: 1.0510 - learning_rate: 1.2500e-04
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9600 - loss: 0.1229 - val_accuracy: 0.7207 - val_loss: 1.0802 - learning_rate: 6.2500e-05
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9630 - loss: 0.1196 - val_accuracy: 0.7289 - val_loss: 1.0790 - learning_rate: 6.2500e-05
# Epoch 31/50
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9516 - loss: 0.1166
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9517 - loss: 0.1166 - val_accuracy: 0.7316 - val_loss: 1.0923 - learning_rate: 6.2500e-05
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9692 - loss: 0.0936 - val_accuracy: 0.7262 - val_loss: 1.1001 - learning_rate: 3.1250e-05
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9700 - loss: 0.1004 - val_accuracy: 0.7316 - val_loss: 1.1263 - learning_rate: 3.1250e-05
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9625 - loss: 0.1042
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9625 - loss: 0.1042 - val_accuracy: 0.7357 - val_loss: 1.1047 - learning_rate: 3.1250e-05
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9670 - loss: 0.1005 - val_accuracy: 0.7275 - val_loss: 1.1411 - learning_rate: 1.5625e-05
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9655 - loss: 0.1002 - val_accuracy: 0.7275 - val_loss: 1.1447 - learning_rate: 1.5625e-05
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9755 - loss: 0.0903
# Epoch 37: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9755 - loss: 0.0903 - val_accuracy: 0.7316 - val_loss: 1.1257 - learning_rate: 1.5625e-05
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9743 - loss: 0.0883 - val_accuracy: 0.7316 - val_loss: 1.1344 - learning_rate: 7.8125e-06
# Epoch 39/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9689 - loss: 0.0928 - val_accuracy: 0.7330 - val_loss: 1.1337 - learning_rate: 7.8125e-06
# Epoch 40/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9656 - loss: 0.0897
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9656 - loss: 0.0897 - val_accuracy: 0.7302 - val_loss: 1.1449 - learning_rate: 7.8125e-06
# Epoch 41/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.9694 - loss: 0.0830 - val_accuracy: 0.7302 - val_loss: 1.1459 - learning_rate: 3.9063e-06
#
# ======================================================================
# Best Results (Epoch 34):
# ======================================================================
#    Training Loss:       0.0981
#    Training Accuracy:   96.49%
#    Validation Loss:     1.1047
#    Validation Accuracy: 73.57%
# ======================================================================
# COMET WARNING: Couldn't retrieve and log Google Colab notebook content, reason: 'NoneType' object is not subscriptable
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : civilian_sea_2293
# COMET INFO:     url                   : https://www.comet.com/mehdi-moha/comet-optimizer/0aa20d1cc12b45bd8aee858bf102ca92
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [41]                 : (0.35320162773132324, 0.9737738370895386)
# COMET INFO:     batch_accuracy [410]          : (0.15625, 1.0)
# COMET INFO:     batch_loss [410]              : (0.034622788429260254, 7.881808280944824)
# COMET INFO:     epoch_duration [41]           : (4.275436416000048, 17.698360102000038)
# COMET INFO:     learning_rate [41]            : (3.906250185536919e-06, 0.0010000000474974513)
# COMET INFO:     loss [41]                     : (0.08194240182638168, 5.853920936584473)
# COMET INFO:     val_accuracy [41]             : (0.2847411334514618, 0.7356948256492615)
# COMET INFO:     val_loss [41]                 : (0.7846662998199463, 1.771244764328003)
# COMET INFO:     validate_batch_accuracy [123] : (0.21875, 0.75)
# COMET INFO:     validate_batch_loss [123]     : (0.7129105925559998, 1.800908088684082)
# COMET INFO:   Others:
# COMET INFO:     class_names            : ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
# COMET INFO:     notebook_url           : https://colab.research.google.com/notebook#fileId=19aPZJGPr4CqvQAZjbetPP1DehjozvW4T
# COMET INFO:     optimizer_count        : 5
# COMET INFO:     optimizer_id           : 4f517a9ca85c4039a0686bf8eef00490
# COMET INFO:     optimizer_metric       : val_accuracy
# COMET INFO:     optimizer_metric_value : 0.7356948256492615
# COMET INFO:     optimizer_name         : Optimize Flower Classifier
# COMET INFO:     optimizer_objective    : maximize
# COMET INFO:     optimizer_parameters   : {"optz": "adam"}
# COMET INFO:     optimizer_pid          : 1283af24e106c2b962b0faaf3a85d5f63810b69f
# COMET INFO:     optimizer_process      : 247
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.1.10
# COMET INFO:     trainable_params       : 11140293
# COMET INFO:   Parameters:
# COMET INFO:     Adam_amsgrad                     : False
# COMET INFO:     Adam_beta_1                      : 0.9
# COMET INFO:     Adam_beta_2                      : 0.999
# COMET INFO:     Adam_clipnorm                    : None
# COMET INFO:     Adam_clipvalue                   : None
# COMET INFO:     Adam_ema_momentum                : 0.99
# COMET INFO:     Adam_ema_overwrite_frequency     : None
# COMET INFO:     Adam_epsilon                     : 1e-07
# COMET INFO:     Adam_global_clipnorm             : None
# COMET INFO:     Adam_gradient_accumulation_steps : None
# COMET INFO:     Adam_learning_rate               : 0.0010000000474974513
# COMET INFO:     Adam_loss_scale_factor           : None
# COMET INFO:     Adam_name                        : adam
# COMET INFO:     Adam_use_ema                     : False
# COMET INFO:     Adam_weight_decay                : None
# COMET INFO:     batch_size                       : 32
# COMET INFO:     epochs                           : 50
# COMET INFO:     img_height                       : 180
# COMET INFO:     img_width                        : 180
# COMET INFO:     num_classes                      : 5
# COMET INFO:     optz                             : adam
# COMET INFO:     steps                            : 92
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# Experiment with adam completed!
# COMET INFO: Optimizer search 4f517a9ca85c4039a0686bf8eef00490 has completed
# ======================================================================
# All optimization experiments complete!
# ======================================================================
#
# Testing model with custom image...
# ======================================================================
# PREDICTION RESULT
# ======================================================================
# Class:      ROSES
# Confidence: 93.54%
# Status:     High confidence
# ======================================================================
#
# Detailed class probabilities:
# ----------------------------------------------------------------------
# 1. roses          :  93.5% ============================================== <- PREDICTED
# 2. tulips         :   6.4% ===
# 3. daisy          :   0.0%
# 4. dandelion      :   0.0%
# 5. sunflowers     :   0.0%
# ----------------------------------------------------------------------
#
# ======================================================================
# ALL TASKS COMPLETED!
# ======================================================================
